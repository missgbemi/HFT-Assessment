# ...                                ...      ...
# 2023-04-11 23:54:00+00:00  1892.502075        0
# 2023-04-11 23:55:00+00:00  1892.528687        0
# 2023-04-11 23:56:00+00:00  1891.994141        0
# 2023-04-11 23:57:00+00:00  1892.116821        0
# 2023-04-11 23:58:00+00:00  1892.393677        0
#
# [1315 rows x 6 columns]

# %%
Bitcoin = BTC['Adj Close']
Bitcoin.plot(figsize=(10, 4), subplots=True)
plt.ylabel('price')
plt.title('Bitcoin price per minute - 11th April 2023')
# Out:
# Text(0.5, 1.0, 'Bitcoin price per minute - 11th April 2023')

# %%
Bitcoin.describe().round(2)      ## Data Description for Bitcoin
# Out:
# count     1315.00
# mean     30122.98
# std        127.83
# min      29609.30
# 25%      30079.58
# 50%      30129.85
# 75%      30207.65
# max      30509.08
# Name: Adj Close, dtype: float64

# %%
Ethereum = ETH['Adj Close']
Ethereum.plot(figsize=(10, 4), subplots=True)
plt.ylabel('price')
plt.title('Ethereum price per minute - 11th April 2023')
# Out:
# Text(0.5, 1.0, 'Ethereum price per minute - 11th April 2023')

# %%
Ethereum.describe().round(2)       # Data Description for Ethereum
# Out:
# count    1315.00
# mean     1912.72
# std        10.54
# min      1886.53
# 25%      1906.87
# 50%      1916.27
# 75%      1920.54
# max      1936.73
# Name: Adj Close, dtype: float64

# %%
S1_0 = BTC['Open'][0]
S2_0 = ETH['Open'][0]

# %%
S1_0    #This represents the starting price i.e the open price for Bitcoin on the 11th April 2023
# Out:
# 29653.6796875

# %%
S2_0    #This represents the starting price i.e the open price for Ethereum on the 11th April 2023
# Out:
# 1911.3758544921875

# %%
# Model inputted and caliberation of 
lr1 = np.log(BTC['Adj Close'] / BTC['Adj Close'].shift(1))
lr2 = np.log(ETH['Adj Close'] / ETH['Adj Close'].shift(1))
mu_1 = lr1.mean() * 1315
mu_2 = lr2.mean() * 1315
sigma_1 = lr1.std() * np.sqrt(1315)
sigma_2 = lr2.std() * np.sqrt(1315)
rho = lr1.corr(lr2)
z_0 = 0.00
gamma = 0.5
delta = 0.8
T = 1
M = len(BTC)

# %%
#calibrate beta
result = linregress(np.log(BTC['Adj Close']), np.log(ETH['Adj Close']))
beta = result.slope

# %%
beta
# Out:
# -0.2830157164839406

# %%
result
# Out:
# LinregressResult(slope=-0.2830157164839406, intercept=10.475015655214193, rvalue=-0.21809835035978184, pvalue=1.2662896828807747e-15, stderr=0.03494966779237192)

# %%
mu_1
# Out:
# 0.019739974956910794

# %%
mu_2
# Out:
# -0.009988397760576577

# %%
sigma_1
# Out:
# 0.021983272875437613

# %%
sigma_2
# Out:
# 0.019152102452920615

# %%
rho
# Out:
# 0.849924793635197

# %%
dt = T/M
S1 = np.zeros((M + 1, 1))
S2 = np.zeros((M + 1, 1))
z =  np.zeros((M + 1, 1))
a =  np.zeros((M + 1, 1))
b =  np.zeros((M + 1, 1))
c =  np.zeros((M + 1, 1))
Pi_1 = np.zeros((M + 1, 1))
Pi_2 = np.zeros((M + 1, 1))

# %% [markdown]
# #### Simulation of the co-integrated factor

# %%
tt = np.linspace(0, 1, M + 1)
z[0] = z_0
S1[0] = S1_0
S2[0] = S2_0
sigma_beta = np.sqrt(sigma_1 ** 2 + beta ** 2 * sigma_2 ** 2 + 2 * beta * sigma_1 * sigma_2 * rho)
eta = (-1/delta) * (mu_1 - sigma_1 ** 2/2 + beta*(mu_2 - sigma_2 ** 2/2))
rn = np.random.standard_normal(z.shape)
for t in range(1, M + 1):
    z[t] = z[t-1]* (1 - delta * (eta - z[t-1])) * dt + sigma_beta * np.sqrt(dt)*((sigma_1 + beta * sigma_2 * rho)/ sigma_beta * rn[t] + beta * (sigma_2 * np.sqrt(1-rho ** 2)/sigma_beta) * rn[t]);
    S1[t] = BTC['Adj Close'][t-1]
    S2[t] = ETH['Adj Close'][t-1]

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, z, 'g', lw=1.5)
plt.xlabel('Time')
plt.ylabel('Rate')
plt.title('z')
# Out:
# Text(0.5, 1.0, 'z')

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))
plt.plot(tt, S1, 'b', lw=1.5, label='BTC')
plt.legend(loc = 5)
plt.xlabel('Time')
plt.ylabel('BTC $')
plt.title('Cryptocurrency Price')
ax2 = ax1.twinx()
plt.plot(tt, S2, 'r', lw=1.5, label='ETH')
plt.legend(loc=0)
plt.ylabel('ETH $');

# %% [markdown]
# #### Optimal Trading Strategy

# %%
for t in range(1, M + 1):
    a[t] = 0.5 * (T - t * dt)/((1-rho ** 2) * sigma_1 ** 2)
    b[t] = - 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2)/((1 - rho ** 2) * sigma_1 ** 2) - rho * mu_2 * (T - t * dt)/((1 - rho **2) * sigma_1 * sigma_2)
    c[t] = 0.5 * mu_2 ** 2 * (T - t * dt)/((1 - rho ** 2) * sigma_2 ** 2) + 0.25 * (T - t * dt) ** 2 * (sigma_1 ** 2 + beta * sigma_2 ** 2 + 2 * sigma_1 * sigma_2 * beta *rho) * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2) + 0.25 * (T - t * dt) ** 2 * mu_2 * delta * rho * (sigma_1 ** 2 + beta * sigma_2 ** 2) + 1/24 * (T - t * dt) ** 3 * (sigma_1 ** 2 + beta * sigma_2 ** 2) ** 2 * delta ** 2/((1 - rho ** 2) * sigma_1 ** 2)
    Pi_1[t] = (1 / S1[t-1]) * ((mu_1 + delta * z[t])/(gamma * (1 - rho ** 2) * sigma_1 ** 2) + delta/gamma * (-2 * a[t] * (mu_1 + delta * z[t])-b[t]) - rho * mu_2/(gamma * (1 - rho ** 2) * sigma_1 * sigma_2))
    Pi_2[t] = (1 / S2[t-1]) * (mu_2 / (gamma * (1 - rho ** 2) * sigma_2 ** 2) + delta * beta / gamma * (- 2 * a[t] * (mu_1 + delta * z[t]) - b[t]) - rho * (mu_1 + delta * z[t]) / (gamma * (1 - rho ** 2) * sigma_1 * sigma_2))

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1, 'b', lw=1.5, label='w1')
plt.plot(tt, Pi_2, 'r', lw=1.5, label='w2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('%')
plt.title('Weights')
# Out:
# Text(0.5, 1.0, 'Weights')

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1, 'b', lw=1.5, label='Wealth 1')
plt.plot(tt, Pi_2 * S2, 'r', lw=1.5, label='Wealth 2')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth = abs(Pi_1 * S1) + abs(Pi_2 * S2)

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt[1:], Wealth[1:], 'b', lw=1.5, label='Total')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Wealth')
# Out:
# Text(0.5, 1.0, 'Wealth')

# %%
Wealth[1]   # Inital Wealth
# Out:
# array([470.08848045])

# %%
Wealth[-1]   # Inital Wealth
# Out:
# array([911.19597652])

# %%
Return = (Wealth[-1] - Wealth[1])/Wealth[1]  # Return
Return.item()
# Out:
# 0.9383499371206966

# %% [markdown]
# #### Comparing with Static control Pair

# %%
Pi_1.mean()
# Out:
# 0.008761971053210315

# %%
Pi_2.mean()
# Out:
# -0.22674883415555686

# %%
plt.figure(figsize=(10, 6))
plt.plot(tt, Pi_1 * S1 + Pi_2 * S2, 'b', lw=1.5, label='Dynamic')
plt.plot(tt, Pi_1.mean() * S1 + Pi_2.mean() * S2, 'r', lw=1.5, label='Static')
plt.legend(loc=0)
plt.xlabel('Time')
plt.ylabel('$')
plt.title('Comparison')
# Out:
# Text(0.5, 1.0, 'Comparison')

# %% [markdown]
# ### Simulation of two assets
